# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
# test drawing
G = nx.petersen_graph()
plt.subplot(121)
nx.draw(G, with_labels=True, font_weight='bold')
# Out:
# /Users/cynthiazhong/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
# random graph with float weights in [0.0, 1.0)
num_nodes = 10
a = np.random.random(size=(num_nodes, num_nodes))
D = nx.Graph(a)
nx.draw(D, with_labels=True)

# %%
f = open("test.in", "w+")
nx.write_weighted_edgelist(D, "test.in")
f.close()
